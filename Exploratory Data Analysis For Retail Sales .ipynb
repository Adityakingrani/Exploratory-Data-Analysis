# %%
#importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the datasetaaaa
df = pd.read_csv("SampleSuperstore.csv")
#checking the first 10 values of the dataset
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
#checking the last 5 values of the dataset
df.tail(5)
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
#checking the shape of the dataset
df.shape
# Out:
# (9994, 13)

# %%
#checking the columns of the dataset
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#checking the data types 
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
#counting the number of values in each column
df.count()
# Out:
# Ship Mode       9994
# Segment         9994
# Country         9994
# City            9994
# State           9994
# Postal Code     9994
# Region          9994
# Category        9994
# Sub-Category    9994
# Sales           9994
# Quantity        9994
# Discount        9994
# Profit          9994
# dtype: int64

# %%
#finding the statistical summary of the dataset
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#checking info on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#finding out any missing value or null value
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# 17

# %%
#dropping the duplicates
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]>

# %%
#unique values in each column
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
print(f"Ship Mode unique values are :- {df['Ship Mode'].unique()} \n\n")

print(f"Segment unique values are :- {df['Segment'].unique()} \n\n")

print(f"Category unique values are :- {df['Category'].unique()} \n\n")

print(f"Region unique values are :- {df['Region'].unique()} \n\n")

print(f"Sub category unique values are :- {df['Sub-Category'].unique()} \n\n")
# Out:
# Ship Mode unique values are :- ['Second Class' 'Standard Class' 'First Class' 'Same Day']
#
#
# Segment unique values are :- ['Consumer' 'Corporate' 'Home Office']
#
#
# Category unique values are :- ['Furniture' 'Office Supplies' 'Technology']
#
#
# Region unique values are :- ['South' 'West' 'Central' 'East']
#
#
# Sub category unique values are :- ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']

# %%
f,ax = plt.subplots(figsize=(19,11))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#checking the outliers
sns.boxplot(x = df['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
sns.boxplot(x = df['Profit'])
# Out:
# <AxesSubplot:xlabel='Profit'>

# %%
sns.boxplot(x = df['Quantity'])
# Out:
# <AxesSubplot:xlabel='Quantity'>

# %%
#plotting a pairplot 
sns.pairplot(df)

# %%
plt.figure(figsize=(20,6))
plt.bar('Sub-Category','Category',data =df)
plt.xlabel("Sub- Category" ,size = 20)
plt.ylabel("Category", size = 20)
# Out:
# Text(0, 0.5, 'Category')

# %%
plt.figure(figsize=(20,6))
plt.bar('Sub-Category','Sales',data =df)
plt.xlabel("Sub- Category" ,size = 20)
plt.ylabel("Sales", size = 20)
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.figure(figsize=(20,6))
plt.bar('Sub-Category','Profit',data =df)
plt.xlabel("Sub- Category" ,size = 20)
plt.ylabel("Profit", size = 20)
# Out:
# Text(0, 0.5, 'Profit')

# %%
plt.figure(figsize=(20,6))
df.groupby('Region')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# Out:
# C:\Users\kingr\AppData\Local\Temp/ipykernel_10208/2716383549.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Region')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# <AxesSubplot:xlabel='Region'>

# %%
plt.figure(figsize=(100,100))
df.groupby('State')['Profit' , 'Sales'].agg(['sum']).plot.bar()
plt.show()
# Out:
# C:\Users\kingr\AppData\Local\Temp/ipykernel_10208/327495491.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('State')['Profit' , 'Sales'].agg(['sum']).plot.bar()

# %%
plt.figure(figsize=(60,20))
df.groupby('Sub-Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# Out:
# C:\Users\kingr\AppData\Local\Temp/ipykernel_10208/2698491337.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Sub-Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# <AxesSubplot:xlabel='Sub-Category'>

# %%
plt.figure(figsize=(60,20))
df.groupby('Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# Out:
# C:\Users\kingr\AppData\Local\Temp/ipykernel_10208/230593646.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# <AxesSubplot:xlabel='Category'>

# %%
sns.countplot(x = df['Segment'])
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
sns.countplot(x = df['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
plt.figure(figsize = (30,10))
sns.barplot(x = df['Sub-Category'], y = df['Profit'])
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Profit'>

# %%
df.hist(bins = 50, figsize=(20,16))
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['Sales'], df['Profit'])
plt.xlabel("Sales",size=20)
plt.ylabel("Profit",size=20)
# Out:
# Text(0, 0.5, 'Profit')
